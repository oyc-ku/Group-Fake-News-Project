# %%
import pandas as pd
from gensim.models import Word2Vec

# %%
stemmed_data = pd.read_csv("./../data/data_stemmed.csv", index_col=0)

# %%
stemmed_data["content"] = stemmed_data["content"].apply(lambda s: s.split(" "))
stemmed_data.head()

# %%
model = Word2Vec(stemmed_content, min_count=1, vector_size=64, window=3)

# %%
# model1.save("model1.model")
