# %%
import os, sys
print("os.environ.get('CONDA_PREFIX'):", os.environ.get('CONDA_PREFIX'))
print("sys.prefix:", sys.prefix)
print("sys.executable:", sys.executable)
print("PATH (first entries):", os.environ.get("PATH", "").split(":")[:3])
prin
# Out:
# os.environ.get('CONDA_PREFIX'): None
# sys.prefix: /opt/conda/envs/python3
# sys.executable: /opt/conda/envs/python3/bin/python
# PATH (first entries): ['/home/jovyan/.local/bin', '/opt/conda/envs/python3/bin', '~/.local/bin']
