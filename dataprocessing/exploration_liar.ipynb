# %%
import pandas as pd

# %%
lair_data=pd.read_csv("E:\KU_MachineLearning_Study\Fake_news_project\Group-Fake-News-Project\evaluation\lair_data_cleaned.csv",)
normal_data=pd.read_csv("E:\KU_MachineLearning_Study\Fake_news_project\Group-Fake-News-Project\linear_regreasion\data_test.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\K'
# <>:2: SyntaxWarning: invalid escape sequence '\K'
# <>:1: SyntaxWarning: invalid escape sequence '\K'
# <>:2: SyntaxWarning: invalid escape sequence '\K'
# C:\Users\hsfac\AppData\Local\Temp\ipykernel_35608\2969121387.py:1: SyntaxWarning: invalid escape sequence '\K'
#   lair_data=pd.read_csv("E:\KU_MachineLearning_Study\Fake_news_project\Group-Fake-News-Project\evaluation\lair_data_cleaned.csv",)
# C:\Users\hsfac\AppData\Local\Temp\ipykernel_35608\2969121387.py:2: SyntaxWarning: invalid escape sequence '\K'
#   normal_data=pd.read_csv("E:\KU_MachineLearning_Study\Fake_news_project\Group-Fake-News-Project\linear_regreasion\data_test.csv")

# %%
def get_avarge_length(t):
    return len(t.split(" "))

# %%
lair_data["length"]=lair_data["content"].apply(get_avarge_length)
normal_data["length"]=normal_data["content"].apply(get_avarge_length)

# %%
print((lair_data["length"].mean()))
print((normal_data["length"].mean()))
# Out:
# 13.606156274664562
# 342.59637260977337
