# %%
import re
import pandas as pd
# Out:
# The kernel failed to start as the Python Environment 'projectGDS (Python -1.-1.-1)' is no longer available. Consider selecting another kernel or refreshing the list of Python Environments.

# %%
data=pd.read_csv("news_sample.csv")
